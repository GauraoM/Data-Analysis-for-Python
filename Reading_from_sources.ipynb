# %% [markdown]
# <a href="https://colab.research.google.com/github/GauraoM/Data-Analysis-for-Python/blob/main/Reading_from_sources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Reading from Sqlite Databases

# %%
import sqlite3
import pandas as pd

# %%
# Connect to the database
conn = sqlite3.connect('sakila.db')

# %%
df = pd.read_sql('SELECT * FROM actor;',conn)

# %%
df
# Out:
#      actor_id first_name     last_name          last_update
# 0           1   PENELOPE       GUINESS  2019-04-11 18:11:48
# 1           2       NICK      WAHLBERG  2019-04-11 18:11:48
# 2           3         ED         CHASE  2019-04-11 18:11:48
# 3           4   JENNIFER         DAVIS  2019-04-11 18:11:48
# 4           5     JOHNNY  LOLLOBRIGIDA  2019-04-11 18:11:48
# ..        ...        ...           ...                  ...
# 195       196       BELA        WALKEN  2019-04-11 18:11:48
# 196       197      REESE          WEST  2019-04-11 18:11:48
# 197       198       MARY        KEITEL  2019-04-11 18:11:48
# 198       199      JULIA       FAWCETT  2019-04-11 18:11:48
# 199       200      THORA        TEMPLE  2019-04-11 18:11:48
#
# [200 rows x 4 columns]

# %% [markdown]
# #### Reading from html

# %%
import requests
import pandas as pd

# %%
html_url = "https://en.wikipedia.org/wiki/The_Simpsons"

# Make request to web pages
r = requests.get(html_url)

# %%
wiki_tables = pd.read_html(r.text, header = 0)

# %%
len(wiki_tables)
# Out:
# 41

# %%
# Reading first table
simpsons = wiki_tables[1]

# %%
simpsons.head()
# Out:
#    Season Season.1  ...          Viewership.1             Viewership.2
# 0  Season   Season  ...  Most watched episode     Most watched episode
# 1  Season   Season  ...     Viewers(millions)            Episode title
# 2       1  1989–90  ...                  33.5  "Life on the Fast Lane"
# 3       2  1990–91  ...                  33.6       "Bart Gets an 'F'"
# 4       3  1991–92  ...                  25.5          "Colonel Homer"
#
# [5 rows x 9 columns]

# %%
# Dropping column
simpsons.drop([0,1], inplace = True)

# %%
# Resetting index
simpsons.set_index('Season',inplace=True)

# %%
simpsons
# Out:
#          Season.1  ...                          Viewership.2
# Season             ...
# 1         1989–90  ...               "Life on the Fast Lane"
# 2         1990–91  ...                    "Bart Gets an 'F'"
# 3         1991–92  ...                       "Colonel Homer"
# 4         1992–93  ...                   "Lisa's First Word"
# 5         1993–94  ...              "Treehouse of Horror IV"
# 6         1994–95  ...               "Treehouse of Horror V"
# 7         1995–96  ...              "Treehouse of Horror VI"
# 8         1996–97  ...               "The Springfield Files"
# 9         1997–98  ...    "The Two Mrs. Nahasapeemapetilons"
# 10        1998–99  ...                  "Maximum Homerdrive"
# 11      1999–2000  ...                  "The Mansion Family"
# 12        2000–01  ...                  "Worst Episode Ever"
# 13        2001–02  ...                      "The Parent Rap"
# 14        2002–03  ...       "I'm Spelling as Fast as I Can"
# ...

# %%
min_season = simpsons['No. ofepisodes'].min()
min_season
# Out:
# '13'
